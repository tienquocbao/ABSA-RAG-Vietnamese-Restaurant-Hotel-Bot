# %%
# !pip install transformer
# !pip install sentencepiece
# !pip install pyvi --quiet
# !pip install --upgrade PyYAML transformers huggingface_hub
# Out:
# ERROR: Could not find a version that satisfies the requirement transformer (from versions: none)
# ERROR: No matching distribution found for transformer
# Requirement already satisfied: sentencepiece in /usr/local/lib/python3.11/dist-packages (0.2.0)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.5/8.5 MB 57.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 59.8 MB/s eta 0:00:00

# %%
import warnings
warnings.filterwarnings('ignore')  # Tắt toàn bộ cảnh báo Python

import os
os.environ["TF_CPP_MIN_LOG_LEVEL"] = "3"      # Tắt cảnh báo TensorFlow (nếu có)
os.environ["TRANSFORMERS_NO_ADVISORY_WARNINGS"] = "true"  # Tắt warning advisory của transformers

# Nếu dùng logging, tắt logging warning
import logging
logging.getLogger("transformers").setLevel(logging.ERROR)
logging.getLogger("pytorch_lightning").setLevel(logging.ERROR)
logging.getLogger("matplotlib").setLevel(logging.ERROR)
logging.getLogger("numba").setLevel(logging.ERROR)
logging.getLogger("datasets").setLevel(logging.ERROR)
from torch.utils.data import Dataset
import pandas as pd
from transformers import T5EncoderModel, AutoTokenizer
import pytorch_lightning as pl
from torch.utils.data import Dataset
import pytorch_lightning as pl
from pytorch_lightning import seed_everything # <--- THÊM DÒNG NÀY
from pytorch_lightning.callbacks import ModelCheckpoint, EarlyStopping
# ... các import khác
# --- ĐẶT SEED TẠI ĐÂY ---
SEED = 42  # Bạn có thể chọn bất kỳ số nào
seed_everything(SEED, workers=True)
# -------------------------
# Out:
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1762490645.882986      19 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1762490645.938037      19 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 42

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F

class AsymmetricLossOptimized(nn.Module):
    ''' Optimized Asymmetric Loss for multi-label/multi-class with imbalance '''

    def __init__(self, gamma_neg=4, gamma_pos=1, clip=0.05, eps=1e-8, disable_torch_grad_focal_loss=False):
        super().__init__()
        self.gamma_neg = gamma_neg
        self.gamma_pos = gamma_pos
        self.clip = clip
        self.disable_torch_grad_focal_loss = disable_torch_grad_focal_loss
        self.eps = eps

        self.targets = self.anti_targets = self.xs_pos = self.xs_neg = self.asymmetric_w = self.loss = None

    def forward(self, x, y):
        # x: logits [B, num_aspects, 4], y: one-hot [B, num_aspects, 4]
        self.targets = y
        self.anti_targets = 1 - y

        # Probabilities
        self.xs_pos = torch.sigmoid(x)
        self.xs_neg = 1.0 - self.xs_pos

        # Asymmetric Clipping
        if self.clip is not None and self.clip > 0:
            self.xs_neg.add_(self.clip).clamp_(max=1)

        # Basic CE
        self.loss = self.targets * torch.log(self.xs_pos.clamp(min=self.eps))
        self.loss.add_(self.anti_targets * torch.log(self.xs_neg.clamp(min=self.eps)))

        # Asymmetric Focusing
        if self.gamma_neg > 0 or self.gamma_pos > 0:
            if self.disable_torch_grad_focal_loss:
                torch.set_grad_enabled(False)
            self.xs_pos = self.xs_pos * self.targets
            self.xs_neg = self.xs_neg * self.anti_targets
            self.asymmetric_w = torch.pow(1 - self.xs_pos - self.xs_neg,
                                          self.gamma_pos * self.targets + self.gamma_neg * self.anti_targets)
            if self.disable_torch_grad_focal_loss:
                torch.set_grad_enabled(True)
            self.loss *= self.asymmetric_w

        return -self.loss.sum() / x.size(0)   # lấy mean loss cho mỗi batch

# %%
def smooth_labels(labels, smoothing=0.1, num_classes=4):
    """
    labels: Tensor [B, num_aspects, num_classes], one-hot.
    smoothing: float, ví dụ 0.1.
    num_classes: int, số class mỗi aspect.
    """
    with torch.no_grad():
        labels = labels * (1 - smoothing) + (smoothing / num_classes)
    return labels

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import pytorch_lightning as pl
from transformers import AutoModel
import math

# 1. Neighborhood Attention
class NeighborhoodAttention(nn.Module):
    def __init__(self, hidden_size: int, num_heads: int = 8, window_size: int = 7):
        super().__init__()
        self.hidden_size = hidden_size
        self.num_heads = num_heads
        self.window_size = window_size
        self.head_dim = hidden_size // num_heads
        self.qkv = nn.Linear(hidden_size, hidden_size * 3, bias=False)
        self.proj = nn.Linear(hidden_size, hidden_size)
        
    def forward(self, x: torch.Tensor, mask: torch.Tensor = None) -> torch.Tensor:
        B, L, C = x.shape
        qkv = self.qkv(x).reshape(B, L, 3, self.num_heads, self.head_dim)
        q, k, v = qkv.permute(2, 0, 3, 1, 4)
        attn_output = []
        for i in range(L):
            start = max(0, i - self.window_size // 2)
            end = min(L, i + self.window_size // 2 + 1)
            q_i = q[:, :, i:i+1, :]
            k_window = k[:, :, start:end, :]
            v_window = v[:, :, start:end, :]
            scores = torch.matmul(q_i, k_window.transpose(-2, -1)) / math.sqrt(self.head_dim)
            attn_weights = F.softmax(scores, dim=-1)
            out_i = torch.matmul(attn_weights, v_window)
            attn_output.append(out_i)
        attn_output = torch.cat(attn_output, dim=2)
        attn_output = attn_output.transpose(1, 2).reshape(B, L, C)
        return self.proj(attn_output)

# 2. StateConvBlock (conv + gating)
class StateConvBlock(nn.Module):
    def __init__(self, hidden_size: int):
        super().__init__()
        inner_dim = hidden_size * 2
        self.in_proj = nn.Linear(hidden_size, inner_dim * 2, bias=False)
        self.conv1d = nn.Conv1d(inner_dim, inner_dim, kernel_size=3, padding=1, groups=inner_dim)
        self.out_proj = nn.Linear(inner_dim, hidden_size, bias=False)
        self.norm = nn.LayerNorm(hidden_size)
    def forward(self, x: torch.Tensor) -> torch.Tensor:
        x_and_res = self.in_proj(x)
        x_inner, res = x_and_res.split(x_and_res.shape[-1] // 2, dim=-1)
        x_inner = self.conv1d(x_inner.transpose(1, 2)).transpose(1, 2)
        x_inner = F.silu(x_inner)
        y = x_inner * F.silu(res)
        output = self.out_proj(y)
        return x + self.norm(output)

# 3. Position Biased Attention + Aspect pooling
class PositionBiasedAttention(nn.Module):
    """
    Multi-head self-attention with positional bias for aspect pooling.
    """
    def __init__(self, hidden_size: int, num_aspects: int):
        super().__init__()
        self.hidden_size = hidden_size
        self.num_aspects = num_aspects
        self.attn = nn.MultiheadAttention(hidden_size, num_heads=8, batch_first=True)
        self.aspect_queries = nn.Parameter(torch.randn(num_aspects, hidden_size))
    def _create_position_bias(self, seq_len: int, device: torch.device) -> torch.Tensor:
        bias = torch.zeros(seq_len, seq_len, device=device)
        for i in range(seq_len):
            for j in range(seq_len):
                distance = abs(i - j)
                if distance > 5:
                    bias[i, j] = -10.0
        return bias
    def forward(self, x: torch.Tensor, attention_mask: torch.Tensor) -> torch.Tensor:
        B, L, D = x.shape
        pos_bias = self._create_position_bias(L, x.device)
        attn_out, _ = self.attn(x, x, x, attn_mask=pos_bias)
        # Aspect pooling: for mỗi aspect, query toàn bộ sequence
        aspect_features = []
        for b in range(B):
            seq_len = attention_mask[b].sum().item()
            keys = attn_out[b, :seq_len].unsqueeze(0)  # [1, seq_len, D]
            queries = self.aspect_queries.unsqueeze(0)  # [1, num_aspects, D]
            # Sử dụng scaled dot-product attention (không dùng Multihead nữa)
            attn_score = torch.matmul(queries, keys.transpose(-2, -1)) / math.sqrt(D)  # [1, num_aspects, seq_len]
            attn_weight = F.softmax(attn_score, dim=-1)
            pooled = torch.matmul(attn_weight, keys)  # [1, num_aspects, D]
            aspect_features.append(pooled.squeeze(0))
        return torch.stack(aspect_features)  # [B, num_aspects, D]

# 4. AdvancedCNN branch
class AdvancedCNN(nn.Module):
    def __init__(self, hidden_size: int, num_filters: int = 128):
        super().__init__()
        self.conv_layers = nn.ModuleList([
            nn.Conv1d(hidden_size, num_filters, kernel_size=3, dilation=1, padding=1),
            nn.Conv1d(hidden_size, num_filters, kernel_size=3, dilation=2, padding=2),
            nn.Conv1d(hidden_size, num_filters, kernel_size=3, dilation=4, padding=4),
        ])
        self.pool = nn.AdaptiveMaxPool1d(1)
        self.fusion = nn.Linear(num_filters * len(self.conv_layers), hidden_size)
    def forward(self, x: torch.Tensor) -> torch.Tensor:
        x = x.transpose(1, 2)
        conv_outputs = []
        for conv in self.conv_layers:
            conv_out = F.relu(conv(x))
            pooled = self.pool(conv_out).squeeze(-1)
            conv_outputs.append(pooled)
        fused = torch.cat(conv_outputs, dim=-1)
        return self.fusion(fused)

# 5. Main ABSA Model
class AdvancedABSAModel(pl.LightningModule):
    def __init__(self, 
                 num_aspects=12, 
                 learning_rate=2e-5, 
                 encoder_name='VietAI/vit5-large',
                 use_neighborhood_attn=True,
                 use_state_conv=True,
                 use_position_attn=True,
                 use_advanced_cnn=True):
        super().__init__()
        self.save_hyperparameters()
        self.num_aspects = num_aspects
        self.encoder = T5EncoderModel.from_pretrained(encoder_name)
        hidden_size = self.encoder.config.d_model

        self.use_neighborhood_attn = use_neighborhood_attn
        self.use_state_conv = use_state_conv
        self.use_position_attn = use_position_attn
        self.use_advanced_cnn = use_advanced_cnn

        if self.use_neighborhood_attn:
            self.neighborhood_attn = NeighborhoodAttention(hidden_size, window_size=7)
        if self.use_state_conv:
            self.state_conv_blocks = nn.ModuleList([StateConvBlock(hidden_size) for _ in range(2)])
        if self.use_position_attn:
            self.position_biased_attn = PositionBiasedAttention(hidden_size, num_aspects)
        if self.use_advanced_cnn:
            self.advanced_cnn = AdvancedCNN(hidden_size)
        self.fusion = nn.Linear(hidden_size * 2, hidden_size)
        self.classifiers = nn.ModuleList([
            nn.Sequential(
                nn.Linear(hidden_size, hidden_size // 2),
                nn.GELU(),
                nn.Dropout(0.1),
                nn.Linear(hidden_size // 2, 4)
            ) for _ in range(num_aspects)
        ])
        self.criterion = AsymmetricLossOptimized(
            gamma_neg=4, gamma_pos=1, clip=0.05, eps=1e-8, disable_torch_grad_focal_loss=False
        )


    def forward(self, input_ids: torch.Tensor, attention_mask: torch.Tensor) -> torch.Tensor:
        encoder_output = self.encoder(input_ids=input_ids, attention_mask=attention_mask)
        x = encoder_output.last_hidden_state  # [B, L, D]
    
        if self.use_neighborhood_attn:
            x_block = self.neighborhood_attn(x, attention_mask)
        else:
            x_block = x
    
        if self.use_state_conv:
            for block in self.state_conv_blocks:
                x_block = block(x_block)
    
        if self.use_position_attn:
            aspect_features = self.position_biased_attn(x_block, attention_mask)  # [B, num_aspects, D]
        else:
            # Global pooling thay thế
            aspect_features = x_block.mean(dim=1, keepdim=True).expand(-1, self.num_aspects, -1)
    
        if self.use_advanced_cnn:
            cnn_features = self.advanced_cnn(x_block)  # [B, D]
        else:
            cnn_features = x_block.mean(dim=1)  # [B, D]
    
        cnn_features = cnn_features.unsqueeze(1).expand(-1, self.num_aspects, -1)  # [B, num_aspects, D]
        fused_features = torch.cat([aspect_features, cnn_features], dim=-1)
        fused_features = self.fusion(fused_features)
        logits = []
        for i, classifier in enumerate(self.classifiers):
            aspect_logits = classifier(fused_features[:, i, :])  # [B, 4]
            logits.append(aspect_logits)
        logits = torch.stack(logits, dim=1)  # [B, num_aspects, 4]
        return logits


    def training_step(self, batch, batch_idx):
        logits = self(batch['input_ids'], batch['attention_mask'])  # [B, num_aspects, 4]
        labels = batch['labels']   # [B, num_aspects] or [B, num_aspects, 4]
        if labels.dim() == 2:
            labels = F.one_hot(labels, num_classes=4).float()
        # --- LABEL SMOOTHING ở đây ---
        labels = smooth_labels(labels, smoothing=0.1, num_classes=4)
        main_loss = self.criterion(logits, labels)
        preds = torch.argmax(logits, dim=-1)
        targets = torch.argmax(labels, dim=-1)
        acc = (preds == targets).float().mean()
        self.log('train_loss', main_loss, prog_bar=True)
        self.log('train_acc', acc, prog_bar=True)
        return main_loss

    def validation_step(self, batch, batch_idx):
        logits = self(batch['input_ids'], batch['attention_mask'])
        labels = batch['labels']
        if labels.dim() == 2:
            labels = F.one_hot(labels, num_classes=4).float()
        preds = torch.argmax(logits, dim=-1)
        targets = torch.argmax(labels, dim=-1)
        acc = (preds == targets).float().mean()
        self.log('val_acc', acc, prog_bar=True)
        return acc

    def configure_optimizers(self):
        optimizer = torch.optim.AdamW(self.parameters(), lr=self.hparams.learning_rate, weight_decay=0.01)
        scheduler = torch.optim.lr_scheduler.CosineAnnealingLR(optimizer, T_max=100, eta_min=1e-7)
        return {
            "optimizer": optimizer,
            "lr_scheduler": {"scheduler": scheduler, "interval": "epoch"}
        }

# %%
class ABSADataset(Dataset):
    def __init__(self, csv_file, tokenizer, max_length=256):
        self.data = pd.read_csv(csv_file)
        self.tokenizer = tokenizer
        self.max_length = max_length
        self.aspect_columns = [col for col in self.data.columns if col != 'Review']
        self.num_aspects = len(self.aspect_columns)

    def __len__(self):
        return len(self.data)

    def __getitem__(self, idx):
        row = self.data.iloc[idx]
        text = str(row['Review'])
        encoding = self.tokenizer(
            text, truncation=True, padding='max_length', max_length=self.max_length, return_tensors='pt'
        )
        labels = []
        for aspect in self.aspect_columns:
            sentiment = int(row[aspect])
            one_hot = [0, 0, 0, 0]
            one_hot[sentiment] = 1
            labels.append(one_hot)
        return {
            'input_ids': encoding['input_ids'].squeeze(),
            'attention_mask': encoding['attention_mask'].squeeze(),
            'labels': torch.tensor(labels, dtype=torch.float),
            'review_text': text
        }

class ABSADataModule(pl.LightningDataModule):
    def __init__(self, train_csv, val_csv, test_csv, tokenizer_name="VietAI/vit5-large", batch_size=16, max_length=256):
        super().__init__()
        self.train_csv = train_csv
        self.val_csv = val_csv
        self.test_csv = test_csv
        self.batch_size = batch_size
        self.max_length = max_length
        self.tokenizer = AutoTokenizer.from_pretrained(tokenizer_name)

    def setup(self, stage=None):
        if stage == 'fit' or stage is None:
            self.train_dataset = ABSADataset(self.train_csv, self.tokenizer, self.max_length)
            self.val_dataset = ABSADataset(self.val_csv, self.tokenizer, self.max_length)
        if stage == 'test' or stage is None:
            self.test_dataset = ABSADataset(self.test_csv, self.tokenizer, self.max_length)

    def train_dataloader(self):
        return DataLoader(self.train_dataset, batch_size=self.batch_size, shuffle=True, generator=torch.Generator(device='cuda'))
    
    def val_dataloader(self):
        return DataLoader(self.val_dataset, batch_size=self.batch_size, shuffle=False)
    
    def test_dataloader(self):
        return DataLoader(self.test_dataset, batch_size=self.batch_size, shuffle=False)

# %%
import os
import pandas as pd
import numpy as np

import torch
from torch.utils.data import Dataset, DataLoader

import pytorch_lightning as pl
from pytorch_lightning.callbacks import ModelCheckpoint, EarlyStopping
from pytorch_lightning.loggers import TensorBoardLogger

# Bạn cần import các thành phần model, tokenizer từ transformers nếu có dùng BERT, Roberta,...
from transformers import AutoTokenizer, AutoModel
from tqdm import tqdm
import logging

# Nếu có cần dùng các tiện ích khác
import random

# Nếu có dùng cuda kiểm tra
if torch.cuda.is_available():
    torch.set_default_tensor_type('torch.cuda.FloatTensor')

# %%
import os
import numpy as np
import torch
from tqdm.notebook import tqdm

idx_to_sentiment = {0: 'None', 1: 'positive', 2: 'negative', 3: 'neutral'}

def generate_prediction_file(model, dataloader, device, output_path, aspect_columns):
    model.eval()
    all_preds = []
    texts = dataloader.dataset.data['Review'].tolist()
    with torch.no_grad():
        for batch in tqdm(dataloader, desc="🔍 Predicting", leave=False):
            input_ids = batch['input_ids'].to(device)
            attention_mask = batch['attention_mask'].to(device)
            outputs = model(input_ids, attention_mask)
            if isinstance(outputs, tuple):
                outputs = outputs[0]
            preds = torch.argmax(outputs, dim=-1).cpu().numpy()
            all_preds.append(preds)
    all_preds = np.vstack(all_preds)
    os.makedirs(os.path.dirname(output_path), exist_ok=True)
    with open(output_path, 'w', encoding='utf-8') as f:
        for i, line in enumerate(texts):
            f.write(f"#{i+1}\n{line}\n")
            aspects = [
                f"{{{aspect_columns[j]}, {idx_to_sentiment[pred]}}}"
                for j, pred in enumerate(all_preds[i]) if pred != 0
            ]
            f.write(", ".join(aspects) + "\n\n" if aspects else "\n\n")
    return output_path

def generate_gold_file(dataloader, output_path, aspect_columns):
    all_labels = []
    texts = dataloader.dataset.data['Review'].tolist()
    for batch in tqdm(dataloader, desc="📄 Loading gold", leave=False):
        labels = batch['labels'].cpu().numpy()  # [B, A, 4]
        all_labels.append(labels)
    all_labels = np.vstack(all_labels)
    os.makedirs(os.path.dirname(output_path), exist_ok=True)
    with open(output_path, 'w', encoding='utf-8') as f:
        for i, line in enumerate(texts):
            f.write(f"#{i+1}\n{line}\n")
            aspects = [
                f"{{{aspect_columns[j]}, {idx_to_sentiment[np.argmax(all_labels[i][j])]}}}"
                for j in range(len(aspect_columns)) if np.argmax(all_labels[i][j]) != 0
            ]
            f.write(", ".join(aspects) + "\n\n" if aspects else "\n\n")
    return output_path

# %%
import re

def get_labels_from_filename(filename):
    """Đọc nhãn từ file prediction/gold theo format:
    #1
    review_text
    {ASPECT1, positive}, {ASPECT2, neutral}
    """
    labels = []
    with open(filename, 'r', encoding='utf-8') as file:
        datasets = file.read()
        count = 0
        for line in datasets.split('\n'):
            if line != '':
                if count == 0:      # ID
                    count += 1
                elif count == 1:    # Review text
                    count += 1
                elif count == 2:    # Aspect-sentiment pairs (hoặc rỗng)
                    labels.append(line.strip())
                    count = 0
            elif count == 2:        # Empty line sau review text (không có aspect)
                labels.append("")
                count = 0
    return labels

def clean_label(label):
    # Chỉ giữ chữ, số, dấu # và &
    label = re.sub('[^A-Za-z0-9#&]', '', label)
    label = re.sub('\\s+', ' ', label)
    return label.strip()

def convert_labels_to_dict(labels):
    """Chuyển 1 dòng nhãn thành dict {aspect: polarity}"""
    dict_labels = []
    for label in labels:
        if not label:
            dict_labels.append({})
            continue
        label_line = label.split('},')
        _dict = {}
        for objectLabel in label_line:
            if not objectLabel.strip():
                continue
            parts = objectLabel.split(',')
            if len(parts) < 2:
                continue
            aspect = clean_label(parts[0]).strip()
            polarity = clean_label(parts[1]).strip()
            _dict[aspect] = polarity
        dict_labels.append(_dict)
    return dict_labels

def get_common_attributeEntities(dict_labels):
    AttributeEntities = []
    for _dict in dict_labels:
        for key in _dict:
            if key not in AttributeEntities:
                AttributeEntities.append(key)
    AttributeEntities = sorted(AttributeEntities)
    return AttributeEntities

def get_aspects(dict_labels):
    aspects = []
    for _dict in dict_labels:
        for key in _dict:
            aspects.append(key)
    return aspects

def count_aspects(labels, Common_AttributeEntities):
    aspects = get_aspects(labels)
    num_aspects = [0] * len(Common_AttributeEntities)
    for aspect in aspects:
        num_aspects[Common_AttributeEntities.index(aspect)] += 1
    return num_aspects

def evaluation_labels(gold_labels, answer_labels, Common_AttributeEntities):
    num_aspect_gold = count_aspects(gold_labels, Common_AttributeEntities)
    num_aspect_answer = count_aspects(answer_labels, Common_AttributeEntities)
    correct_answer_aspects = [0] * len(Common_AttributeEntities)
    correct_answer_labels = [0] * len(Common_AttributeEntities)

    for i, _dict in enumerate(answer_labels):
        for key in _dict:
            if key in gold_labels[i].keys():
                correct_answer_aspects[Common_AttributeEntities.index(key)] += 1
                if answer_labels[i][key].lower() == gold_labels[i][key].lower():
                    correct_answer_labels[Common_AttributeEntities.index(key)] += 1
    print('Correct Aspect Detection per Aspect:', correct_answer_aspects)
    print('Correct Aspect+Sentiment Detection:', correct_answer_labels)
    print('---------------------------------------------------')
    print('Aspect Detection Metrics:')
    infor_evaluation(correct_answer_aspects, num_aspect_answer, num_aspect_gold, Common_AttributeEntities)
    print('---------------------------------------------------')
    print('Aspect+Sentiment Detection Metrics:')
    infor_evaluation(correct_answer_labels, num_aspect_answer, num_aspect_gold, Common_AttributeEntities)

def infor_evaluation(correct_answer, num_aspect_answer, num_aspect_gold, Common_AttributeEntities):
    for idx, aspect in enumerate(Common_AttributeEntities):
        if correct_answer[idx] == 0:
            p = r = f = 0.0
        else:
            p = correct_answer[idx] * 100 / num_aspect_answer[idx] if num_aspect_answer[idx] > 0 else 0.0
            r = correct_answer[idx] * 100 / num_aspect_gold[idx] if num_aspect_gold[idx] > 0 else 0.0
            f = 2 * p * r / (p + r) if (p + r) > 0 else 0.0
        print(f"{aspect}: Precision={p:.2f}, Recall={r:.2f}, F1={f:.2f}")
    p = sum(correct_answer) * 100 / sum(num_aspect_answer) if sum(num_aspect_answer) > 0 else 0.0
    r = sum(correct_answer) * 100 / sum(num_aspect_gold) if sum(num_aspect_gold) > 0 else 0.0
    f = 2 * p * r / (p + r) if (p + r) > 0 else 0.0
    print('-------------------------------------------------------------')
    print(f'Mean Precision: {round(p,2)}')
    print(f'Mean Recall: {round(r,2)}')
    print(f'Mean F1: {round(f,2)}')
    print('-------------------------------------------------------------')

def evaluation_system(gold_labels, answer_labels):
    gold_dicts = convert_labels_to_dict(gold_labels)
    answer_dicts = convert_labels_to_dict(answer_labels)
    AttributeEntities = get_common_attributeEntities(gold_dicts)
    evaluation_labels(gold_dicts, answer_dicts, AttributeEntities)

def evaluation_system_by_file(file_gold, file_predict):
    gold_labels = get_labels_from_filename(file_gold)
    answer_labels = get_labels_from_filename(file_predict)
    evaluation_system(gold_labels, answer_labels)

# %%
ablation_settings = [
    # # 1. Tắt Neighborhood Attention
    # {"use_neighborhood_attn": False, "use_state_conv": True, "use_position_attn": True, "use_advanced_cnn": True},

    # # 2. Tắt StateConvBlock
    # {"use_neighborhood_attn": True, "use_state_conv": False, "use_position_attn": True, "use_advanced_cnn": True},

    # # 3. Tắt Position Biased Attention
    # {"use_neighborhood_attn": True, "use_state_conv": True, "use_position_attn": False, "use_advanced_cnn": True},

    # # 4. Tắt AdvancedCNN
    # {"use_neighborhood_attn": True, "use_state_conv": True, "use_position_attn": True, "use_advanced_cnn": False},

    # # 5. Tắt hết (chỉ dùng backbone encoder, ablation "full vanilla")
    # {"use_neighborhood_attn": False, "use_state_conv": False, "use_position_attn": False, "use_advanced_cnn": False},

    # # 6. Tắt Neighborhood Attention + StateConvBlock (giữ 2 module cuối)
    # {"use_neighborhood_attn": False, "use_state_conv": False, "use_position_attn": True, "use_advanced_cnn": True},

    # # 7. Tắt StateConvBlock + Position Attention
    # {"use_neighborhood_attn": True, "use_state_conv": False, "use_position_attn": False, "use_advanced_cnn": True},

    # # 8. Tắt Position Attention + AdvancedCNN
    # {"use_neighborhood_attn": True, "use_state_conv": True, "use_position_attn": False, "use_advanced_cnn": False},

    # # 9. Tắt Neighborhood Attention + AdvancedCNN
    # {"use_neighborhood_attn": False, "use_state_conv": True, "use_position_attn": True, "use_advanced_cnn": False},

    # # 10. Tắt Neighborhood Attention + Position Attention
    # {"use_neighborhood_attn": False, "use_state_conv": True, "use_position_attn": False, "use_advanced_cnn": True},

    # 11. Tắt StateConvBlock + AdvancedCNN
    # {"use_neighborhood_attn": True, "use_state_conv": False, "use_position_attn": True, "use_advanced_cnn": False},

    # 12. Tắt Neighborhood Attention + StateConvBlock + Position Attention
    # {"use_neighborhood_attn": False, "use_state_conv": False, "use_position_attn": False, "use_advanced_cnn": True},

    # 13. Tắt Neighborhood Attention + StateConvBlock + AdvancedCNN
    # {"use_neighborhood_attn": False, "use_state_conv": False, "use_position_attn": True, "use_advanced_cnn": False},

    # 14. Tắt Neighborhood Attention + Position Attention + AdvancedCNN
    # {"use_neighborhood_attn": False, "use_state_conv": True, "use_position_attn": False, "use_advanced_cnn": False},

    # 15. Tắt StateConvBlock + Position Attention + AdvancedCNN
    # {"use_neighborhood_attn": True, "use_state_conv": False, "use_position_attn": False, "use_advanced_cnn": False},
    # 16. Có đầy đủ các thành phần 
    {"use_neighborhood_attn": True, "use_state_conv": True, "use_position_attn": True, "use_advanced_cnn": True}
]

model_type="VietAI/vit5-base"
learning_rate=2e-5
batch_size=16
max_epochs=20
gpus=1
train_csv="/kaggle/input/uit-hotel-absa/Train.csv"
val_csv="/kaggle/input/uit-hotel-absa/Dev.csv"
test_csv="/kaggle/input/uit-hotel-absa/Test.csv"
max_length=128
checkpoint_dir="/kaggle/working/"
log_dir="/kaggle/working/"
mixed_precision=True
accumulate_grad_batches=1

print("🚀 Starting Advanced ABSA Training...")
print(f"📊 Configuration:")
print(f"   - Model: {model_type}")
print(f"   - Learning Rate: {learning_rate}")
print(f"   - Batch Size: {batch_size}")
print(f"   - Max Epochs: {max_epochs}")
print(f"   - GPU: {gpus}")

import pytorch_lightning as pl

class EvaluateOnTestSetCallback(pl.Callback):
    def __init__(self, test_dataloader, aspect_columns, gold_file_path, predict_file_path, device):
        self.test_dataloader = test_dataloader
        self.aspect_columns = aspect_columns
        self.gold_file_path = gold_file_path
        self.predict_file_path = predict_file_path
        self.device = device

    def on_validation_epoch_end(self, trainer, pl_module):
        print("-" * 10)
        epoch = trainer.current_epoch + 1  # Đếm từ 1
        print(f"\nEvaluating on Test Set - Epoch {epoch}:")
        print("-" * 10)
        # Gọi hàm generate prediction/gold
        generate_prediction_file(pl_module, self.test_dataloader, self.device, self.predict_file_path, self.aspect_columns)
        generate_gold_file(self.test_dataloader, self.gold_file_path, self.aspect_columns)
        # Evaluate
        evaluation_system_by_file(self.gold_file_path, self.predict_file_path)



# Setup data module
dm = ABSADataModule(
    train_csv=train_csv,
    val_csv=val_csv,
    test_csv=test_csv,
    batch_size=batch_size,
    max_length=max_length,
    tokenizer_name=model_type
)

# Get number of aspects from dataset
dm.setup()
num_aspects = dm.train_dataset.num_aspects
aspect_columns = dm.test_dataloader().dataset.aspect_columns
print(f"   - Number of Aspects: {num_aspects}")

count = 0
for setting in ablation_settings:
    print(f"Running ablation: {count+1}", setting)
    model = AdvancedABSAModel(num_aspects=num_aspects , learning_rate=learning_rate, encoder_name='VietAI/vit5-large', **setting)
    early_stopping = EarlyStopping(monitor="val_acc", mode="max", patience=2, verbose=True)
         
    evaluate_callback = EvaluateOnTestSetCallback(
        test_dataloader=dm.test_dataloader(),
        aspect_columns=aspect_columns,          
        gold_file_path="predictions/test_predictions.txt",
        predict_file_path="predictions/gold_labels.txt",
        device='cuda' if torch.cuda.is_available() else 'cpu'
    )
    checkpoint_callback = ModelCheckpoint(
        dirpath=checkpoint_dir,  # Thư mục lưu model (đã định nghĩa là "/kaggle/working/")
        filename=f"ablation_{count+1}_best_model", # Tên file, thêm count để phân biệt
        monitor="val_acc",       # Theo dõi chỉ số 'val_acc'
        mode="max",              # Lưu model khi chỉ số này lớn nhất
        save_top_k=1,            # Chỉ lưu 1 model tốt nhất
        verbose=True
    )

    # Setup trainer
    trainer = pl.Trainer(
        max_epochs=max_epochs,
        accelerator="auto",
        # THÊM checkpoint_callback VÀO ĐÂY:
        callbacks=[early_stopping, evaluate_callback, checkpoint_callback],
        precision=16 if mixed_precision else 32,
        gradient_clip_val=1.0,
        accumulate_grad_batches=accumulate_grad_batches,
        check_val_every_n_epoch=1,
        log_every_n_steps=449,
        logger=False,
        enable_checkpointing=True
    )
    
    # Train model
    print("\n🔥 Starting Training...")
    trainer.fit(model, dm)
    
    print(f"\n✅ Training Complete!")
# Out:
# 🚀 Starting Advanced ABSA Training...
# 📊 Configuration:
#    - Model: VietAI/vit5-base
#    - Learning Rate: 2e-05
#    - Batch Size: 16
#    - Max Epochs: 20
#    - GPU: 1
# tokenizer_config.json: 0.00B [00:00, ?B/s]
# spiece.model:   0%|          | 0.00/820k [00:00<?, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# special_tokens_map.json: 0.00B [00:00, ?B/s]
#    - Number of Aspects: 34
# Running ablation: 1 {'use_neighborhood_attn': True, 'use_state_conv': True, 'use_position_attn': True, 'use_advanced_cnn': True}
# config.json:   0%|          | 0.00/640 [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/3.17G [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/3.17G [00:00<?, ?B/s]
# 🔥 Starting Training...
# Sanity Checking: |          | 0/? [00:00<?, ?it/s]
# ----------
#
# Evaluating on Test Set - Epoch 1:
# ----------
# 🔍 Predicting:   0%|          | 0/127 [00:00<?, ?it/s]
# 📄 Loading gold:   0%|          | 0/127 [00:00<?, ?it/s]
# Correct Aspect Detection per Aspect: [14, 6, 17, 45, 11, 5, 21, 9, 5, 70, 61, 52, 55, 1, 333, 24, 174, 78, 266, 14, 12, 30, 31, 38, 1, 40, 115, 51, 135, 49, 11, 4, 59, 634]
# Correct Aspect+Sentiment Detection: [8, 1, 8, 4, 4, 1, 5, 3, 0, 24, 39, 46, 6, 0, 257, 2, 70, 11, 24, 2, 7, 3, 4, 5, 1, 3, 22, 1, 10, 11, 2, 3, 42, 513]
# ---------------------------------------------------
# Aspect Detection Metrics:
# FACILITIES#CLEANLINESS: Precision=0.94, Recall=87.50, F1=1.86
# FACILITIES#COMFORT: Precision=0.30, Recall=100.00, F1=0.59
# FACILITIES#DESIGN&FEATURES: Precision=0.84, Recall=100.00, F1=1.67
# FACILITIES#GENERAL: Precision=2.22, Recall=100.00, F1=4.34
# FACILITIES#MISCELLANEOUS: Precision=0.55, Recall=100.00, F1=1.08
# FACILITIES#PRICES: Precision=0.74, Recall=83.33, F1=1.46
# FACILITIES#QUALITY: Precision=1.08, Recall=95.45, F1=2.14
# FOOD&DRINKS#MISCELLANEOUS: Precision=0.45, Recall=100.00, F1=0.89
# FOOD&DRINKS#PRICES: Precision=0.31, Recall=62.50, F1=0.62
# FOOD&DRINKS#QUALITY: Precision=5.31, Recall=68.63, F1=9.86
# FOOD&DRINKS#STYLE&OPTIONS: Precision=5.46, Recall=82.43, F1=10.24
# HOTEL#CLEANLINESS: Precision=2.57, Recall=100.00, F1=5.00
# HOTEL#COMFORT: Precision=11.98, Recall=21.57, F1=15.41
# HOTEL#DESIGN&FEATURES: Precision=20.00, Recall=1.27, F1=2.38
# HOTEL#GENERAL: Precision=16.59, Recall=99.11, F1=28.43
# HOTEL#MISCELLANEOUS: Precision=1.30, Recall=100.00, F1=2.56
# HOTEL#PRICES: Precision=8.57, Recall=100.00, F1=15.79
# HOTEL#QUALITY: Precision=3.86, Recall=98.73, F1=7.43
# LOCATION#GENERAL: Precision=13.13, Recall=100.00, F1=23.21
# ROOMAMENITIES#CLEANLINESS: Precision=0.69, Recall=100.00, F1=1.37
# ROOMAMENITIES#COMFORT: Precision=0.59, Recall=100.00, F1=1.18
# ROOMAMENITIES#DESIGN&FEATURES: Precision=1.48, Recall=100.00, F1=2.91
# ROOMAMENITIES#GENERAL: Precision=7.65, Recall=15.90, F1=10.33
# ROOMAMENITIES#MISCELLANEOUS: Precision=1.88, Recall=100.00, F1=3.68
# ROOMAMENITIES#PRICES: Precision=0.05, Recall=100.00, F1=0.10
# ROOMAMENITIES#QUALITY: Precision=2.86, Recall=65.57, F1=5.48
# ROOMS#CLEANLINESS: Precision=11.09, Recall=39.25, F1=17.29
# ROOMS#COMFORT: Precision=5.32, Recall=47.66, F1=9.58
# ROOMS#DESIGN&FEATURES: Precision=6.65, Recall=100.00, F1=12.47
# ROOMS#GENERAL: Precision=3.29, Recall=72.06, F1=6.29
# ROOMS#MISCELLANEOUS: Precision=0.54, Recall=100.00, F1=1.08
# ROOMS#PRICES: Precision=0.50, Recall=23.53, F1=0.99
# ROOMS#QUALITY: Precision=2.91, Recall=100.00, F1=5.65
# SERVICE#GENERAL: Precision=31.42, Recall=99.37, F1=47.74
# -------------------------------------------------------------
# Mean Precision: 4.5
# Mean Recall: 75.8
# Mean F1: 8.49
# -------------------------------------------------------------
# ---------------------------------------------------
# Aspect+Sentiment Detection Metrics:
# FACILITIES#CLEANLINESS: Precision=0.54, Recall=50.00, F1=1.06
# FACILITIES#COMFORT: Precision=0.05, Recall=16.67, F1=0.10
# FACILITIES#DESIGN&FEATURES: Precision=0.40, Recall=47.06, F1=0.78
# FACILITIES#GENERAL: Precision=0.20, Recall=8.89, F1=0.39
# FACILITIES#MISCELLANEOUS: Precision=0.20, Recall=36.36, F1=0.39
# FACILITIES#PRICES: Precision=0.15, Recall=16.67, F1=0.29
# FACILITIES#QUALITY: Precision=0.26, Recall=22.73, F1=0.51
# FOOD&DRINKS#MISCELLANEOUS: Precision=0.15, Recall=33.33, F1=0.30
# FOOD&DRINKS#PRICES: Precision=0.00, Recall=0.00, F1=0.00
# FOOD&DRINKS#QUALITY: Precision=1.82, Recall=23.53, F1=3.38
# FOOD&DRINKS#STYLE&OPTIONS: Precision=3.49, Recall=52.70, F1=6.55
# HOTEL#CLEANLINESS: Precision=2.27, Recall=88.46, F1=4.43
# HOTEL#COMFORT: Precision=1.31, Recall=2.35, F1=1.68
# HOTEL#DESIGN&FEATURES: Precision=0.00, Recall=0.00, F1=0.00
# HOTEL#GENERAL: Precision=12.81, Recall=76.49, F1=21.94
# HOTEL#MISCELLANEOUS: Precision=0.11, Recall=8.33, F1=0.21
# HOTEL#PRICES: Precision=3.45, Recall=40.23, F1=6.35
# HOTEL#QUALITY: Precision=0.54, Recall=13.92, F1=1.05
# LOCATION#GENERAL: Precision=1.18, Recall=9.02, F1=2.09
# ROOMAMENITIES#CLEANLINESS: Precision=0.10, Recall=14.29, F1=0.20
# ROOMAMENITIES#COMFORT: Precision=0.35, Recall=58.33, F1=0.69
# ROOMAMENITIES#DESIGN&FEATURES: Precision=0.15, Recall=10.00, F1=0.29
# ROOMAMENITIES#GENERAL: Precision=0.99, Recall=2.05, F1=1.33
# ROOMAMENITIES#MISCELLANEOUS: Precision=0.25, Recall=13.16, F1=0.48
# ROOMAMENITIES#PRICES: Precision=0.05, Recall=100.00, F1=0.10
# ROOMAMENITIES#QUALITY: Precision=0.21, Recall=4.92, F1=0.41
# ROOMS#CLEANLINESS: Precision=2.12, Recall=7.51, F1=3.31
# ROOMS#COMFORT: Precision=0.10, Recall=0.93, F1=0.19
# ROOMS#DESIGN&FEATURES: Precision=0.49, Recall=7.41, F1=0.92
# ROOMS#GENERAL: Precision=0.74, Recall=16.18, F1=1.41
# ROOMS#MISCELLANEOUS: Precision=0.10, Recall=18.18, F1=0.20
# ROOMS#PRICES: Precision=0.38, Recall=17.65, F1=0.74
# ROOMS#QUALITY: Precision=2.07, Recall=71.19, F1=4.02
# SERVICE#GENERAL: Precision=25.42, Recall=80.41, F1=38.63
# -------------------------------------------------------------
# Mean Precision: 2.08
# Mean Recall: 35.03
# Mean F1: 3.92
# -------------------------------------------------------------
# Training: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# ----------
#
# Evaluating on Test Set - Epoch 1:
# ----------
# 🔍 Predicting:   0%|          | 0/127 [00:00<?, ?it/s]
# 📄 Loading gold:   0%|          | 0/127 [00:00<?, ?it/s]
# Correct Aspect Detection per Aspect: [0, 0, 0, 0, 0, 0, 0, 0, 1, 78, 62, 3, 169, 44, 161, 0, 146, 40, 264, 0, 0, 0, 183, 12, 0, 3, 256, 21, 56, 2, 0, 0, 12, 585]
# Correct Aspect+Sentiment Detection: [0, 0, 0, 0, 0, 0, 0, 0, 1, 70, 53, 3, 153, 44, 123, 0, 125, 30, 257, 0, 0, 0, 180, 11, 0, 3, 246, 18, 47, 1, 0, 0, 12, 541]
# ---------------------------------------------------
# Aspect Detection Metrics:
# FACILITIES#CLEANLINESS: Precision=0.00, Recall=0.00, F1=0.00
# FACILITIES#COMFORT: Precision=0.00, Recall=0.00, F1=0.00
# FACILITIES#DESIGN&FEATURES: Precision=0.00, Recall=0.00, F1=0.00
# FACILITIES#GENERAL: Precision=0.00, Recall=0.00, F1=0.00
# FACILITIES#MISCELLANEOUS: Precision=0.00, Recall=0.00, F1=0.00
# FACILITIES#PRICES: Precision=0.00, Recall=0.00, F1=0.00
# FACILITIES#QUALITY: Precision=0.00, Recall=0.00, F1=0.00
# FOOD&DRINKS#MISCELLANEOUS: Precision=0.00, Recall=0.00, F1=0.00
# FOOD&DRINKS#PRICES: Precision=100.00, Recall=12.50, F1=22.22
# FOOD&DRINKS#QUALITY: Precision=70.91, Recall=76.47, F1=73.58
# FOOD&DRINKS#STYLE&OPTIONS: Precision=71.26, Recall=83.78, F1=77.02
# HOTEL#CLEANLINESS: Precision=100.00, Recall=5.77, F1=10.91
# HOTEL#COMFORT: Precision=80.09, Recall=66.27, F1=72.53
# HOTEL#DESIGN&FEATURES: Precision=60.27, Recall=55.70, F1=57.89
# HOTEL#GENERAL: Precision=90.45, Recall=47.92, F1=62.65
# HOTEL#MISCELLANEOUS: Precision=0.00, Recall=0.00, F1=0.00
# HOTEL#PRICES: Precision=90.12, Recall=83.91, F1=86.90
# HOTEL#QUALITY: Precision=86.96, Recall=50.63, F1=64.00
# LOCATION#GENERAL: Precision=91.99, Recall=99.25, F1=95.48
# ROOMAMENITIES#CLEANLINESS: Precision=0.00, Recall=0.00, F1=0.00
# ROOMAMENITIES#COMFORT: Precision=0.00, Recall=0.00, F1=0.00
# ROOMAMENITIES#DESIGN&FEATURES: Precision=0.00, Recall=0.00, F1=0.00
# ROOMAMENITIES#GENERAL: Precision=80.97, Recall=93.85, F1=86.94
# ROOMAMENITIES#MISCELLANEOUS: Precision=46.15, Recall=31.58, F1=37.50
# ROOMAMENITIES#PRICES: Precision=0.00, Recall=0.00, F1=0.00
# ROOMAMENITIES#QUALITY: Precision=100.00, Recall=4.92, F1=9.38
# ROOMS#CLEANLINESS: Precision=86.20, Recall=87.37, F1=86.78
# ROOMS#COMFORT: Precision=72.41, Recall=19.63, F1=30.88
# ROOMS#DESIGN&FEATURES: Precision=87.50, Recall=41.48, F1=56.28
# ROOMS#GENERAL: Precision=100.00, Recall=2.94, F1=5.71
# ROOMS#MISCELLANEOUS: Precision=0.00, Recall=0.00, F1=0.00
# ROOMS#PRICES: Precision=0.00, Recall=0.00, F1=0.00
# ROOMS#QUALITY: Precision=92.31, Recall=20.34, F1=33.33
# SERVICE#GENERAL: Precision=91.41, Recall=91.69, F1=91.55
# -------------------------------------------------------------
# Mean Precision: 85.35
# Mean Recall: 64.36
# Mean F1: 73.38
# -------------------------------------------------------------
# ---------------------------------------------------
# Aspect+Sentiment Detection Metrics:
# FACILITIES#CLEANLINESS: Precision=0.00, Recall=0.00, F1=0.00
# FACILITIES#COMFORT: Precision=0.00, Recall=0.00, F1=0.00
# FACILITIES#DESIGN&FEATURES: Precision=0.00, Recall=0.00, F1=0.00
# FACILITIES#GENERAL: Precision=0.00, Recall=0.00, F1=0.00
# FACILITIES#MISCELLANEOUS: Precision=0.00, Recall=0.00, F1=0.00
# FACILITIES#PRICES: Precision=0.00, Recall=0.00, F1=0.00
# FACILITIES#QUALITY: Precision=0.00, Recall=0.00, F1=0.00
# FOOD&DRINKS#MISCELLANEOUS: Precision=0.00, Recall=0.00, F1=0.00
# FOOD&DRINKS#PRICES: Precision=100.00, Recall=12.50, F1=22.22
# FOOD&DRINKS#QUALITY: Precision=63.64, Recall=68.63, F1=66.04
# FOOD&DRINKS#STYLE&OPTIONS: Precision=60.92, Recall=71.62, F1=65.84
# HOTEL#CLEANLINESS: Precision=100.00, Recall=5.77, F1=10.91
# HOTEL#COMFORT: Precision=72.51, Recall=60.00, F1=65.67
# HOTEL#DESIGN&FEATURES: Precision=60.27, Recall=55.70, F1=57.89
# HOTEL#GENERAL: Precision=69.10, Recall=36.61, F1=47.86
# HOTEL#MISCELLANEOUS: Precision=0.00, Recall=0.00, F1=0.00
# HOTEL#PRICES: Precision=77.16, Recall=71.84, F1=74.40
# HOTEL#QUALITY: Precision=65.22, Recall=37.97, F1=48.00
# LOCATION#GENERAL: Precision=89.55, Recall=96.62, F1=92.95
# ROOMAMENITIES#CLEANLINESS: Precision=0.00, Recall=0.00, F1=0.00
# ROOMAMENITIES#COMFORT: Precision=0.00, Recall=0.00, F1=0.00
# ROOMAMENITIES#DESIGN&FEATURES: Precision=0.00, Recall=0.00, F1=0.00
# ROOMAMENITIES#GENERAL: Precision=79.65, Recall=92.31, F1=85.51
# ROOMAMENITIES#MISCELLANEOUS: Precision=42.31, Recall=28.95, F1=34.38
# ROOMAMENITIES#PRICES: Precision=0.00, Recall=0.00, F1=0.00
# ROOMAMENITIES#QUALITY: Precision=100.00, Recall=4.92, F1=9.38
# ROOMS#CLEANLINESS: Precision=82.83, Recall=83.96, F1=83.39
# ROOMS#COMFORT: Precision=62.07, Recall=16.82, F1=26.47
# ROOMS#DESIGN&FEATURES: Precision=73.44, Recall=34.81, F1=47.24
# ROOMS#GENERAL: Precision=50.00, Recall=1.47, F1=2.86
# ROOMS#MISCELLANEOUS: Precision=0.00, Recall=0.00, F1=0.00
# ROOMS#PRICES: Precision=0.00, Recall=0.00, F1=0.00
# ROOMS#QUALITY: Precision=92.31, Recall=20.34, F1=33.33
# SERVICE#GENERAL: Precision=84.53, Recall=84.80, F1=84.66
# -------------------------------------------------------------
# Mean Precision: 78.03
# Mean Recall: 58.83
# Mean F1: 67.09
# -------------------------------------------------------------
# Validation: |          | 0/? [00:00<?, ?it/s]
# ----------
#
# Evaluating on Test Set - Epoch 2:
# ----------
# 🔍 Predicting:   0%|          | 0/127 [00:00<?, ?it/s]
# 📄 Loading gold:   0%|          | 0/127 [00:00<?, ?it/s]
# Correct Aspect Detection per Aspect: [7, 0, 7, 15, 4, 2, 10, 1, 1, 91, 62, 25, 200, 55, 193, 0, 161, 54, 239, 11, 3, 1, 184, 14, 0, 38, 275, 76, 88, 14, 0, 9, 42, 604]
# Correct Aspect+Sentiment Detection: [7, 0, 5, 15, 4, 2, 9, 1, 1, 87, 53, 24, 188, 52, 146, 0, 150, 40, 234, 7, 2, 1, 179, 14, 0, 29, 265, 74, 77, 9, 0, 5, 37, 569]
# ---------------------------------------------------
# Aspect Detection Metrics:
# FACILITIES#CLEANLINESS: Precision=87.50, Recall=43.75, F1=58.33
# FACILITIES#COMFORT: Precision=0.00, Recall=0.00, F1=0.00
# FACILITIES#DESIGN&FEATURES: Precision=100.00, Recall=41.18, F1=58.33
# FACILITIES#GENERAL: Precision=45.45, Recall=33.33, F1=38.46
# FACILITIES#MISCELLANEOUS: Precision=44.44, Recall=36.36, F1=40.00
# FACILITIES#PRICES: Precision=66.67, Recall=33.33, F1=44.44
# FACILITIES#QUALITY: Precision=66.67, Recall=45.45, F1=54.05
# FOOD&DRINKS#MISCELLANEOUS: Precision=33.33, Recall=11.11, F1=16.67
# FOOD&DRINKS#PRICES: Precision=100.00, Recall=12.50, F1=22.22
# FOOD&DRINKS#QUALITY: Precision=90.10, Recall=89.22, F1=89.66
# FOOD&DRINKS#STYLE&OPTIONS: Precision=92.54, Recall=83.78, F1=87.94
# HOTEL#CLEANLINESS: Precision=89.29, Recall=48.08, F1=62.50
# HOTEL#COMFORT: Precision=74.63, Recall=78.43, F1=76.48
# HOTEL#DESIGN&FEATURES: Precision=70.51, Recall=69.62, F1=70.06
# HOTEL#GENERAL: Precision=81.78, Recall=57.44, F1=67.48
# HOTEL#MISCELLANEOUS: Precision=0.00, Recall=0.00, F1=0.00
# HOTEL#PRICES: Precision=86.10, Recall=92.53, F1=89.20
# HOTEL#QUALITY: Precision=73.97, Recall=68.35, F1=71.05
# LOCATION#GENERAL: Precision=97.15, Recall=89.85, F1=93.36
# ROOMAMENITIES#CLEANLINESS: Precision=57.89, Recall=78.57, F1=66.67
# ROOMAMENITIES#COMFORT: Precision=33.33, Recall=25.00, F1=28.57
# ROOMAMENITIES#DESIGN&FEATURES: Precision=50.00, Recall=3.33, F1=6.25
# ROOMAMENITIES#GENERAL: Precision=81.42, Recall=94.36, F1=87.41
# ROOMAMENITIES#MISCELLANEOUS: Precision=46.67, Recall=36.84, F1=41.18
# ROOMAMENITIES#PRICES: Precision=0.00, Recall=0.00, F1=0.00
# ROOMAMENITIES#QUALITY: Precision=59.38, Recall=62.30, F1=60.80
# ROOMS#CLEANLINESS: Precision=89.29, Recall=93.86, F1=91.51
# ROOMS#COMFORT: Precision=63.33, Recall=71.03, F1=66.96
# ROOMS#DESIGN&FEATURES: Precision=78.57, Recall=65.19, F1=71.26
# ROOMS#GENERAL: Precision=93.33, Recall=20.59, F1=33.73
# ROOMS#MISCELLANEOUS: Precision=0.00, Recall=0.00, F1=0.00
# ROOMS#PRICES: Precision=52.94, Recall=52.94, F1=52.94
# ROOMS#QUALITY: Precision=70.00, Recall=71.19, F1=70.59
# SERVICE#GENERAL: Precision=86.66, Recall=94.67, F1=90.49
# -------------------------------------------------------------
# Mean Precision: 81.67
# Mean Recall: 76.26
# Mean F1: 78.87
# -------------------------------------------------------------
# ---------------------------------------------------
# Aspect+Sentiment Detection Metrics:
# FACILITIES#CLEANLINESS: Precision=87.50, Recall=43.75, F1=58.33
# FACILITIES#COMFORT: Precision=0.00, Recall=0.00, F1=0.00
# FACILITIES#DESIGN&FEATURES: Precision=71.43, Recall=29.41, F1=41.67
# FACILITIES#GENERAL: Precision=45.45, Recall=33.33, F1=38.46
# FACILITIES#MISCELLANEOUS: Precision=44.44, Recall=36.36, F1=40.00
# FACILITIES#PRICES: Precision=66.67, Recall=33.33, F1=44.44
# FACILITIES#QUALITY: Precision=60.00, Recall=40.91, F1=48.65
# FOOD&DRINKS#MISCELLANEOUS: Precision=33.33, Recall=11.11, F1=16.67
# FOOD&DRINKS#PRICES: Precision=100.00, Recall=12.50, F1=22.22
# FOOD&DRINKS#QUALITY: Precision=86.14, Recall=85.29, F1=85.71
# FOOD&DRINKS#STYLE&OPTIONS: Precision=79.10, Recall=71.62, F1=75.18
# HOTEL#CLEANLINESS: Precision=85.71, Recall=46.15, F1=60.00
# HOTEL#COMFORT: Precision=70.15, Recall=73.73, F1=71.89
# HOTEL#DESIGN&FEATURES: Precision=66.67, Recall=65.82, F1=66.24
# HOTEL#GENERAL: Precision=61.86, Recall=43.45, F1=51.05
# HOTEL#MISCELLANEOUS: Precision=0.00, Recall=0.00, F1=0.00
# HOTEL#PRICES: Precision=80.21, Recall=86.21, F1=83.10
# HOTEL#QUALITY: Precision=54.79, Recall=50.63, F1=52.63
# LOCATION#GENERAL: Precision=95.12, Recall=87.97, F1=91.41
# ROOMAMENITIES#CLEANLINESS: Precision=36.84, Recall=50.00, F1=42.42
# ROOMAMENITIES#COMFORT: Precision=22.22, Recall=16.67, F1=19.05
# ROOMAMENITIES#DESIGN&FEATURES: Precision=50.00, Recall=3.33, F1=6.25
# ROOMAMENITIES#GENERAL: Precision=79.20, Recall=91.79, F1=85.04
# ROOMAMENITIES#MISCELLANEOUS: Precision=46.67, Recall=36.84, F1=41.18
# ROOMAMENITIES#PRICES: Precision=0.00, Recall=0.00, F1=0.00
# ROOMAMENITIES#QUALITY: Precision=45.31, Recall=47.54, F1=46.40
# ROOMS#CLEANLINESS: Precision=86.04, Recall=90.44, F1=88.19
# ROOMS#COMFORT: Precision=61.67, Recall=69.16, F1=65.20
# ROOMS#DESIGN&FEATURES: Precision=68.75, Recall=57.04, F1=62.35
# ROOMS#GENERAL: Precision=60.00, Recall=13.24, F1=21.69
# ROOMS#MISCELLANEOUS: Precision=0.00, Recall=0.00, F1=0.00
# ROOMS#PRICES: Precision=29.41, Recall=29.41, F1=29.41
# ROOMS#QUALITY: Precision=61.67, Recall=62.71, F1=62.18
# SERVICE#GENERAL: Precision=81.64, Recall=89.18, F1=85.24
# -------------------------------------------------------------
# Mean Precision: 75.1
# Mean Recall: 70.12
# Mean F1: 72.53
# -------------------------------------------------------------
# Validation: |          | 0/? [00:00<?, ?it/s]
# ----------
#
# Evaluating on Test Set - Epoch 3:
# ----------
# 🔍 Predicting:   0%|          | 0/127 [00:00<?, ?it/s]
# 📄 Loading gold:   0%|          | 0/127 [00:00<?, ?it/s]
# Correct Aspect Detection per Aspect: [10, 0, 3, 13, 0, 2, 8, 1, 1, 89, 65, 32, 177, 37, 187, 8, 165, 61, 256, 1, 3, 3, 171, 6, 0, 25, 271, 42, 95, 14, 1, 13, 41, 506]
# Correct Aspect+Sentiment Detection: [7, 0, 2, 12, 0, 2, 7, 1, 1, 86, 59, 30, 168, 37, 138, 4, 152, 47, 251, 1, 2, 3, 169, 6, 0, 24, 262, 40, 80, 11, 1, 8, 36, 484]
# ---------------------------------------------------
# Aspect Detection Metrics:
# FACILITIES#CLEANLINESS: Precision=100.00, Recall=62.50, F1=76.92
# FACILITIES#COMFORT: Precision=0.00, Recall=0.00, F1=0.00
# FACILITIES#DESIGN&FEATURES: Precision=100.00, Recall=17.65, F1=30.00
# FACILITIES#GENERAL: Precision=54.17, Recall=28.89, F1=37.68
# FACILITIES#MISCELLANEOUS: Precision=0.00, Recall=0.00, F1=0.00
# FACILITIES#PRICES: Precision=66.67, Recall=33.33, F1=44.44
# FACILITIES#QUALITY: Precision=66.67, Recall=36.36, F1=47.06
# FOOD&DRINKS#MISCELLANEOUS: Precision=100.00, Recall=11.11, F1=20.00
# FOOD&DRINKS#PRICES: Precision=100.00, Recall=12.50, F1=22.22
# FOOD&DRINKS#QUALITY: Precision=89.90, Recall=87.25, F1=88.56
# FOOD&DRINKS#STYLE&OPTIONS: Precision=94.20, Recall=87.84, F1=90.91
# HOTEL#CLEANLINESS: Precision=82.05, Recall=61.54, F1=70.33
# HOTEL#COMFORT: Precision=83.10, Recall=69.41, F1=75.64
# HOTEL#DESIGN&FEATURES: Precision=72.55, Recall=46.84, F1=56.92
# HOTEL#GENERAL: Precision=86.98, Recall=55.65, F1=67.88
# HOTEL#MISCELLANEOUS: Precision=57.14, Recall=33.33, F1=42.11
# HOTEL#PRICES: Precision=88.24, Recall=94.83, F1=91.41
# HOTEL#QUALITY: Precision=65.59, Recall=77.22, F1=70.93
# LOCATION#GENERAL: Precision=95.17, Recall=96.24, F1=95.70
# ROOMAMENITIES#CLEANLINESS: Precision=100.00, Recall=7.14, F1=13.33
# ROOMAMENITIES#COMFORT: Precision=100.00, Recall=25.00, F1=40.00
# ROOMAMENITIES#DESIGN&FEATURES: Precision=60.00, Recall=10.00, F1=17.14
# ROOMAMENITIES#GENERAL: Precision=89.06, Recall=87.69, F1=88.37
# ROOMAMENITIES#MISCELLANEOUS: Precision=66.67, Recall=15.79, F1=25.53
# ROOMAMENITIES#PRICES: Precision=0.00, Recall=0.00, F1=0.00
# ROOMAMENITIES#QUALITY: Precision=67.57, Recall=40.98, F1=51.02
# ROOMS#CLEANLINESS: Precision=92.18, Recall=92.49, F1=92.33
# ROOMS#COMFORT: Precision=75.00, Recall=39.25, F1=51.53
# ROOMS#DESIGN&FEATURES: Precision=79.17, Recall=70.37, F1=74.51
# ROOMS#GENERAL: Precision=73.68, Recall=20.59, F1=32.18
# ROOMS#MISCELLANEOUS: Precision=20.00, Recall=9.09, F1=12.50
# ROOMS#PRICES: Precision=54.17, Recall=76.47, F1=63.41
# ROOMS#QUALITY: Precision=82.00, Recall=69.49, F1=75.23
# SERVICE#GENERAL: Precision=94.40, Recall=79.31, F1=86.20
# -------------------------------------------------------------
# Mean Precision: 86.93
# Mean Recall: 70.77
# Mean F1: 78.02
# -------------------------------------------------------------
# ---------------------------------------------------
# Aspect+Sentiment Detection Metrics:
# FACILITIES#CLEANLINESS: Precision=70.00, Recall=43.75, F1=53.85
# FACILITIES#COMFORT: Precision=0.00, Recall=0.00, F1=0.00
# FACILITIES#DESIGN&FEATURES: Precision=66.67, Recall=11.76, F1=20.00
# FACILITIES#GENERAL: Precision=50.00, Recall=26.67, F1=34.78
# FACILITIES#MISCELLANEOUS: Precision=0.00, Recall=0.00, F1=0.00
# FACILITIES#PRICES: Precision=66.67, Recall=33.33, F1=44.44
# FACILITIES#QUALITY: Precision=58.33, Recall=31.82, F1=41.18
# FOOD&DRINKS#MISCELLANEOUS: Precision=100.00, Recall=11.11, F1=20.00
# FOOD&DRINKS#PRICES: Precision=100.00, Recall=12.50, F1=22.22
# FOOD&DRINKS#QUALITY: Precision=86.87, Recall=84.31, F1=85.57
# FOOD&DRINKS#STYLE&OPTIONS: Precision=85.51, Recall=79.73, F1=82.52
# HOTEL#CLEANLINESS: Precision=76.92, Recall=57.69, F1=65.93
# HOTEL#COMFORT: Precision=78.87, Recall=65.88, F1=71.79
# HOTEL#DESIGN&FEATURES: Precision=72.55, Recall=46.84, F1=56.92
# HOTEL#GENERAL: Precision=64.19, Recall=41.07, F1=50.09
# HOTEL#MISCELLANEOUS: Precision=28.57, Recall=16.67, F1=21.05
# HOTEL#PRICES: Precision=81.28, Recall=87.36, F1=84.21
# HOTEL#QUALITY: Precision=50.54, Recall=59.49, F1=54.65
# LOCATION#GENERAL: Precision=93.31, Recall=94.36, F1=93.83
# ROOMAMENITIES#CLEANLINESS: Precision=100.00, Recall=7.14, F1=13.33
# ROOMAMENITIES#COMFORT: Precision=66.67, Recall=16.67, F1=26.67
# ROOMAMENITIES#DESIGN&FEATURES: Precision=60.00, Recall=10.00, F1=17.14
# ROOMAMENITIES#GENERAL: Precision=88.02, Recall=86.67, F1=87.34
# ROOMAMENITIES#MISCELLANEOUS: Precision=66.67, Recall=15.79, F1=25.53
# ROOMAMENITIES#PRICES: Precision=0.00, Recall=0.00, F1=0.00
# ROOMAMENITIES#QUALITY: Precision=64.86, Recall=39.34, F1=48.98
# ROOMS#CLEANLINESS: Precision=89.12, Recall=89.42, F1=89.27
# ROOMS#COMFORT: Precision=71.43, Recall=37.38, F1=49.08
# ROOMS#DESIGN&FEATURES: Precision=66.67, Recall=59.26, F1=62.75
# ROOMS#GENERAL: Precision=57.89, Recall=16.18, F1=25.29
# ROOMS#MISCELLANEOUS: Precision=20.00, Recall=9.09, F1=12.50
# ROOMS#PRICES: Precision=33.33, Recall=47.06, F1=39.02
# ROOMS#QUALITY: Precision=72.00, Recall=61.02, F1=66.06
# SERVICE#GENERAL: Precision=90.30, Recall=75.86, F1=82.45
# -------------------------------------------------------------
# Mean Precision: 80.29
# Mean Recall: 65.37
# Mean F1: 72.07
# -------------------------------------------------------------
# Validation: |          | 0/? [00:00<?, ?it/s]
# ----------
#
# Evaluating on Test Set - Epoch 4:
# ----------
# 🔍 Predicting:   0%|          | 0/127 [00:00<?, ?it/s]
# 📄 Loading gold:   0%|          | 0/127 [00:00<?, ?it/s]
# Correct Aspect Detection per Aspect: [12, 0, 10, 18, 3, 3, 16, 1, 0, 89, 71, 33, 191, 53, 239, 4, 165, 62, 252, 6, 8, 12, 169, 8, 0, 27, 275, 67, 98, 38, 1, 10, 42, 575]
# Correct Aspect+Sentiment Detection: [12, 0, 8, 17, 3, 3, 14, 1, 0, 81, 65, 31, 176, 48, 192, 1, 150, 52, 240, 6, 5, 10, 165, 8, 0, 21, 265, 65, 85, 30, 1, 6, 37, 536]
# ---------------------------------------------------
# Aspect Detection Metrics:
# FACILITIES#CLEANLINESS: Precision=92.31, Recall=75.00, F1=82.76
# FACILITIES#COMFORT: Precision=0.00, Recall=0.00, F1=0.00
# FACILITIES#DESIGN&FEATURES: Precision=76.92, Recall=58.82, F1=66.67
# FACILITIES#GENERAL: Precision=52.94, Recall=40.00, F1=45.57
# FACILITIES#MISCELLANEOUS: Precision=50.00, Recall=27.27, F1=35.29
# FACILITIES#PRICES: Precision=75.00, Recall=50.00, F1=60.00
# FACILITIES#QUALITY: Precision=48.48, Recall=72.73, F1=58.18
# FOOD&DRINKS#MISCELLANEOUS: Precision=33.33, Recall=11.11, F1=16.67
# FOOD&DRINKS#PRICES: Precision=0.00, Recall=0.00, F1=0.00
# FOOD&DRINKS#QUALITY: Precision=92.71, Recall=87.25, F1=89.90
# FOOD&DRINKS#STYLE&OPTIONS: Precision=84.52, Recall=95.95, F1=89.87
# HOTEL#CLEANLINESS: Precision=82.50, Recall=63.46, F1=71.74
# HOTEL#COMFORT: Precision=76.71, Recall=74.90, F1=75.79
# HOTEL#DESIGN&FEATURES: Precision=67.09, Recall=67.09, F1=67.09
# HOTEL#GENERAL: Precision=71.99, Recall=71.13, F1=71.56
# HOTEL#MISCELLANEOUS: Precision=40.00, Recall=16.67, F1=23.53
# HOTEL#PRICES: Precision=90.16, Recall=94.83, F1=92.44
# HOTEL#QUALITY: Precision=72.94, Recall=78.48, F1=75.61
# LOCATION#GENERAL: Precision=96.92, Recall=94.74, F1=95.82
# ROOMAMENITIES#CLEANLINESS: Precision=66.67, Recall=42.86, F1=52.17
# ROOMAMENITIES#COMFORT: Precision=38.10, Recall=66.67, F1=48.48
# ROOMAMENITIES#DESIGN&FEATURES: Precision=36.36, Recall=40.00, F1=38.10
# ROOMAMENITIES#GENERAL: Precision=83.66, Recall=86.67, F1=85.14
# ROOMAMENITIES#MISCELLANEOUS: Precision=42.11, Recall=21.05, F1=28.07
# ROOMAMENITIES#PRICES: Precision=0.00, Recall=0.00, F1=0.00
# ROOMAMENITIES#QUALITY: Precision=61.36, Recall=44.26, F1=51.43
# ROOMS#CLEANLINESS: Precision=90.76, Recall=93.86, F1=92.28
# ROOMS#COMFORT: Precision=64.42, Recall=62.62, F1=63.51
# ROOMS#DESIGN&FEATURES: Precision=69.50, Recall=72.59, F1=71.01
# ROOMS#GENERAL: Precision=58.46, Recall=55.88, F1=57.14
# ROOMS#MISCELLANEOUS: Precision=100.00, Recall=9.09, F1=16.67
# ROOMS#PRICES: Precision=71.43, Recall=58.82, F1=64.52
# ROOMS#QUALITY: Precision=80.77, Recall=71.19, F1=75.68
# SERVICE#GENERAL: Precision=91.56, Recall=90.13, F1=90.84
# -------------------------------------------------------------
# Mean Precision: 80.92
# Mean Recall: 78.47
# Mean F1: 79.68
# -------------------------------------------------------------
# ---------------------------------------------------
# Aspect+Sentiment Detection Metrics:
# FACILITIES#CLEANLINESS: Precision=92.31, Recall=75.00, F1=82.76
# FACILITIES#COMFORT: Precision=0.00, Recall=0.00, F1=0.00
# FACILITIES#DESIGN&FEATURES: Precision=61.54, Recall=47.06, F1=53.33
# FACILITIES#GENERAL: Precision=50.00, Recall=37.78, F1=43.04
# FACILITIES#MISCELLANEOUS: Precision=50.00, Recall=27.27, F1=35.29
# FACILITIES#PRICES: Precision=75.00, Recall=50.00, F1=60.00
# FACILITIES#QUALITY: Precision=42.42, Recall=63.64, F1=50.91
# FOOD&DRINKS#MISCELLANEOUS: Precision=33.33, Recall=11.11, F1=16.67
# FOOD&DRINKS#PRICES: Precision=0.00, Recall=0.00, F1=0.00
# FOOD&DRINKS#QUALITY: Precision=84.38, Recall=79.41, F1=81.82
# FOOD&DRINKS#STYLE&OPTIONS: Precision=77.38, Recall=87.84, F1=82.28
# HOTEL#CLEANLINESS: Precision=77.50, Recall=59.62, F1=67.39
# HOTEL#COMFORT: Precision=70.68, Recall=69.02, F1=69.84
# HOTEL#DESIGN&FEATURES: Precision=60.76, Recall=60.76, F1=60.76
# HOTEL#GENERAL: Precision=57.83, Recall=57.14, F1=57.49
# HOTEL#MISCELLANEOUS: Precision=10.00, Recall=4.17, F1=5.88
# HOTEL#PRICES: Precision=81.97, Recall=86.21, F1=84.03
# HOTEL#QUALITY: Precision=61.18, Recall=65.82, F1=63.41
# LOCATION#GENERAL: Precision=92.31, Recall=90.23, F1=91.25
# ROOMAMENITIES#CLEANLINESS: Precision=66.67, Recall=42.86, F1=52.17
# ROOMAMENITIES#COMFORT: Precision=23.81, Recall=41.67, F1=30.30
# ROOMAMENITIES#DESIGN&FEATURES: Precision=30.30, Recall=33.33, F1=31.75
# ROOMAMENITIES#GENERAL: Precision=81.68, Recall=84.62, F1=83.12
# ROOMAMENITIES#MISCELLANEOUS: Precision=42.11, Recall=21.05, F1=28.07
# ROOMAMENITIES#PRICES: Precision=0.00, Recall=0.00, F1=0.00
# ROOMAMENITIES#QUALITY: Precision=47.73, Recall=34.43, F1=40.00
# ROOMS#CLEANLINESS: Precision=87.46, Recall=90.44, F1=88.93
# ROOMS#COMFORT: Precision=62.50, Recall=60.75, F1=61.61
# ROOMS#DESIGN&FEATURES: Precision=60.28, Recall=62.96, F1=61.59
# ROOMS#GENERAL: Precision=46.15, Recall=44.12, F1=45.11
# ROOMS#MISCELLANEOUS: Precision=100.00, Recall=9.09, F1=16.67
# ROOMS#PRICES: Precision=42.86, Recall=35.29, F1=38.71
# ROOMS#QUALITY: Precision=71.15, Recall=62.71, F1=66.67
# SERVICE#GENERAL: Precision=85.35, Recall=84.01, F1=84.68
# -------------------------------------------------------------
# Mean Precision: 73.84
# Mean Recall: 71.6
# Mean F1: 72.7
# -------------------------------------------------------------
# Validation: |          | 0/? [00:00<?, ?it/s]
# ----------
#
# Evaluating on Test Set - Epoch 5:
# ----------
# 🔍 Predicting:   0%|          | 0/127 [00:00<?, ?it/s]
# 📄 Loading gold:   0%|          | 0/127 [00:00<?, ?it/s]
# Correct Aspect Detection per Aspect: [14, 0, 8, 18, 1, 1, 17, 1, 2, 99, 70, 29, 187, 62, 240, 1, 163, 62, 259, 8, 3, 4, 180, 15, 0, 32, 283, 77, 86, 33, 1, 10, 39, 564]
# Correct Aspect+Sentiment Detection: [14, 0, 4, 17, 1, 1, 16, 1, 2, 95, 57, 28, 172, 56, 195, 1, 152, 51, 250, 8, 2, 4, 174, 15, 0, 31, 272, 75, 74, 27, 1, 8, 36, 529]
# ---------------------------------------------------
# Aspect Detection Metrics:
# FACILITIES#CLEANLINESS: Precision=93.33, Recall=87.50, F1=90.32
# FACILITIES#COMFORT: Precision=0.00, Recall=0.00, F1=0.00
# FACILITIES#DESIGN&FEATURES: Precision=88.89, Recall=47.06, F1=61.54
# FACILITIES#GENERAL: Precision=48.65, Recall=40.00, F1=43.90
# FACILITIES#MISCELLANEOUS: Precision=33.33, Recall=9.09, F1=14.29
# FACILITIES#PRICES: Precision=100.00, Recall=16.67, F1=28.57
# FACILITIES#QUALITY: Precision=53.12, Recall=77.27, F1=62.96
# FOOD&DRINKS#MISCELLANEOUS: Precision=20.00, Recall=11.11, F1=14.29
# FOOD&DRINKS#PRICES: Precision=66.67, Recall=25.00, F1=36.36
# FOOD&DRINKS#QUALITY: Precision=81.15, Recall=97.06, F1=88.39
# FOOD&DRINKS#STYLE&OPTIONS: Precision=80.46, Recall=94.59, F1=86.96
# HOTEL#CLEANLINESS: Precision=76.32, Recall=55.77, F1=64.44
# HOTEL#COMFORT: Precision=78.90, Recall=73.33, F1=76.02
# HOTEL#DESIGN&FEATURES: Precision=67.39, Recall=78.48, F1=72.51
# HOTEL#GENERAL: Precision=72.95, Recall=71.43, F1=72.18
# HOTEL#MISCELLANEOUS: Precision=25.00, Recall=4.17, F1=7.14
# HOTEL#PRICES: Precision=89.56, Recall=93.68, F1=91.57
# HOTEL#QUALITY: Precision=70.45, Recall=78.48, F1=74.25
# LOCATION#GENERAL: Precision=95.93, Recall=97.37, F1=96.64
# ROOMAMENITIES#CLEANLINESS: Precision=61.54, Recall=57.14, F1=59.26
# ROOMAMENITIES#COMFORT: Precision=75.00, Recall=25.00, F1=37.50
# ROOMAMENITIES#DESIGN&FEATURES: Precision=40.00, Recall=13.33, F1=20.00
# ROOMAMENITIES#GENERAL: Precision=85.31, Recall=92.31, F1=88.67
# ROOMAMENITIES#MISCELLANEOUS: Precision=42.86, Recall=39.47, F1=41.10
# ROOMAMENITIES#PRICES: Precision=0.00, Recall=0.00, F1=0.00
# ROOMAMENITIES#QUALITY: Precision=65.31, Recall=52.46, F1=58.18
# ROOMS#CLEANLINESS: Precision=87.89, Recall=96.59, F1=92.03
# ROOMS#COMFORT: Precision=57.04, Recall=71.96, F1=63.64
# ROOMS#DESIGN&FEATURES: Precision=82.69, Recall=63.70, F1=71.97
# ROOMS#GENERAL: Precision=70.21, Recall=48.53, F1=57.39
# ROOMS#MISCELLANEOUS: Precision=100.00, Recall=9.09, F1=16.67
# ROOMS#PRICES: Precision=83.33, Recall=58.82, F1=68.97
# ROOMS#QUALITY: Precision=84.78, Recall=66.10, F1=74.29
# SERVICE#GENERAL: Precision=91.11, Recall=88.40, F1=89.74
# -------------------------------------------------------------
# Mean Precision: 81.25
# Mean Recall: 78.8
# Mean F1: 80.01
# -------------------------------------------------------------
# ---------------------------------------------------
# Aspect+Sentiment Detection Metrics:
# FACILITIES#CLEANLINESS: Precision=93.33, Recall=87.50, F1=90.32
# FACILITIES#COMFORT: Precision=0.00, Recall=0.00, F1=0.00
# FACILITIES#DESIGN&FEATURES: Precision=44.44, Recall=23.53, F1=30.77
# FACILITIES#GENERAL: Precision=45.95, Recall=37.78, F1=41.46
# FACILITIES#MISCELLANEOUS: Precision=33.33, Recall=9.09, F1=14.29
# FACILITIES#PRICES: Precision=100.00, Recall=16.67, F1=28.57
# FACILITIES#QUALITY: Precision=50.00, Recall=72.73, F1=59.26
# FOOD&DRINKS#MISCELLANEOUS: Precision=20.00, Recall=11.11, F1=14.29
# FOOD&DRINKS#PRICES: Precision=66.67, Recall=25.00, F1=36.36
# FOOD&DRINKS#QUALITY: Precision=77.87, Recall=93.14, F1=84.82
# FOOD&DRINKS#STYLE&OPTIONS: Precision=65.52, Recall=77.03, F1=70.81
# HOTEL#CLEANLINESS: Precision=73.68, Recall=53.85, F1=62.22
# HOTEL#COMFORT: Precision=72.57, Recall=67.45, F1=69.92
# HOTEL#DESIGN&FEATURES: Precision=60.87, Recall=70.89, F1=65.50
# HOTEL#GENERAL: Precision=59.27, Recall=58.04, F1=58.65
# HOTEL#MISCELLANEOUS: Precision=25.00, Recall=4.17, F1=7.14
# HOTEL#PRICES: Precision=83.52, Recall=87.36, F1=85.39
# HOTEL#QUALITY: Precision=57.95, Recall=64.56, F1=61.08
# LOCATION#GENERAL: Precision=92.59, Recall=93.98, F1=93.28
# ROOMAMENITIES#CLEANLINESS: Precision=61.54, Recall=57.14, F1=59.26
# ROOMAMENITIES#COMFORT: Precision=50.00, Recall=16.67, F1=25.00
# ROOMAMENITIES#DESIGN&FEATURES: Precision=40.00, Recall=13.33, F1=20.00
# ROOMAMENITIES#GENERAL: Precision=82.46, Recall=89.23, F1=85.71
# ROOMAMENITIES#MISCELLANEOUS: Precision=42.86, Recall=39.47, F1=41.10
# ROOMAMENITIES#PRICES: Precision=0.00, Recall=0.00, F1=0.00
# ROOMAMENITIES#QUALITY: Precision=63.27, Recall=50.82, F1=56.36
# ROOMS#CLEANLINESS: Precision=84.47, Recall=92.83, F1=88.46
# ROOMS#COMFORT: Precision=55.56, Recall=70.09, F1=61.98
# ROOMS#DESIGN&FEATURES: Precision=71.15, Recall=54.81, F1=61.92
# ROOMS#GENERAL: Precision=57.45, Recall=39.71, F1=46.96
# ROOMS#MISCELLANEOUS: Precision=100.00, Recall=9.09, F1=16.67
# ROOMS#PRICES: Precision=66.67, Recall=47.06, F1=55.17
# ROOMS#QUALITY: Precision=78.26, Recall=61.02, F1=68.57
# SERVICE#GENERAL: Precision=85.46, Recall=82.92, F1=84.17
# -------------------------------------------------------------
# Mean Precision: 74.92
# Mean Recall: 72.67
# Mean F1: 73.78
# -------------------------------------------------------------
#
# ✅ Training Complete!
